# %% [markdown]
# 1. Addition, subtraction, multiplication, division

# %% [markdown]
# (a) Add 24345 to 32373

# %%
24345 + 32373
# Out:
# 56718

# %% [markdown]
# (b) Add 3.6 to 2.7

# %%
3.6 + 2.7
# Out:
# 6.300000000000001

# %% [markdown]
# (c) Subtract 45263 from 320574

# %%
320574 - 45263
# Out:
# 275311

# %% [markdown]
# (d) Subtract 3.7 from 6.2

# %%
6.2 - 3.7
# Out:
# 2.5

# %% [markdown]
# (e) Multiply 352 by 84

# %%
352 * 84
# Out:
# 29568

# %% [markdown]
# (f) Multiply 23.5 by 47.32

# %%
23.5 * 47.32
# Out:
# 1112.02

# %% [markdown]
# (g) Divide 267 by 524

# %%
267 / 524
# Out:
# 0.5095419847328244

# %% [markdown]
# (h) Divide 266.2 by 60.356

# %%
266.2 / 60.356
# Out:
# 4.410497713566174

# %% [markdown]
# (i) Multiply 241 by 3.41

# %%
241 * 3.41
# Out:
# 821.8100000000001

# %% [markdown]
# (j) Divide 23 by 51.31

# %%
23 / 51.31
# Out:
# 0.44825570064314946

# %% [markdown]
# 2. Integer division, modulus, precedence

# %% [markdown]
# (a) Integer divide 75 by 3

# %%
75 // 3
# Out:
# 25

# %% [markdown]
# (b) Integer divide 245 by 93

# %%
245 // 93
# Out:
# 2

# %% [markdown]
# (c) Integer divide -32 by 5

# %%
-32 // 5
# Out:
# -7

# %% [markdown]
# (d) Find the remainder for 245 divided by 93

# %%
245 % 93
# Out:
# 59

# %% [markdown]
# (e) Find the remainder for 629 divided by 204

# %%
629 % 204
# Out:
# 17

# %% [markdown]
# (f) Add 2 to 5, then divide by 3

# %%
(2 + 5) / 3
# Out:
# 2.3333333333333335

# %% [markdown]
# (g) Find the remainder for the operation in (f)

# %%
(2 + 5) % 3
# Out:
# 1

# %% [markdown]
# (h) Subtract 3 from 8, then multiply by 24

# %%
(8 - 3) * 24
# Out:
# 120

# %% [markdown]
# (i) Add 53.4 to 4.25, and then multiply by 4.49

# %%
(53.4 + 4.25) * 4.49
# Out:
# 258.8485

# %% [markdown]
# (j) Add 74.32 to 3.91, and then divide by 5.14

# %%
(74.32 + 3.91) / 5.14
# Out:
# 15.219844357976653
